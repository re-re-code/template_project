# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Hello, World!")

x = np.array([0, 1])
y = pd.Series([0, 1])
print(x)
print(y)

plt.plot(x, y)
# Out:
# Hello, World!
# [0 1]
# 0    0
# 1    1
# dtype: int64
